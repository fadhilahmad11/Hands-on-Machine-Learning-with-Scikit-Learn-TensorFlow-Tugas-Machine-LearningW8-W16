# %% [markdown]
# <a href="https://colab.research.google.com/github/fadhilahmad11/Hands-on-Machine-Learning-with-Scikit-Learn-TensorFlow-Tugas-Machine-LearningW8-W16/blob/main/Chapter_01_The_Machine_Learning_Landscape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1: The Machine Learning Landscape
#
# ---
#
# ## 1. Pendahuluan
# Machine Learning (ML) telah hadir dalam berbagai aspek kehidupan kita, mulai dari filter spam pada email hingga rekomendasi produk di e-commerce.
# Chapter ini membahas:
# - Peta konsep Machine Learning
# - Tipe-tipe sistem Machine Learning
# - Tantangan dalam mengembangkan model
# - Dasar evaluasi dan validasi model
#
# ---
#
# ## 2. Definisi Machine Learning
#
# **Arthur Samuel (1959)**
# > *"Machine Learning is the field of study that gives computers the ability to learn without being explicitly programmed."*
#
# **Tom Mitchell (1997)**
# > *"A computer program is said to learn from experience $E$ with respect to some task $T$ and some performance measure $P$, if its performance on $T$, as measured by $P$, improves with experience $E$."*
#
# Contoh: Spam filter belajar ($E$) dari email berlabel spam/ham ($T$) untuk meningkatkan akurasi ($P$).
#
# ---
#
# ## 3. Mengapa Menggunakan Machine Learning
#
# ML sangat berguna untuk:
# - Masalah kompleks tanpa aturan eksplisit (misalnya speech recognition)
# - Lingkungan yang dinamis (misalnya spam filter)
# - Menemukan pola tersembunyi (data mining)
# - Mengurangi hardcoding aturan rumit
#
# ---
#
# ## 4. Contoh Aplikasi Machine Learning
#
# - **Image classification**: deteksi produk rusak (CNN)
# - **Speech recognition**: perintah suara (RNN, Transformer)
# - **Text classification**: filter spam, deteksi komentar kasar
# - **Recommender systems**: rekomendasi produk
# - **Anomaly detection**: transaksi kartu kredit mencurigakan
# - **Clustering**: segmentasi pelanggan
# - **Reinforcement learning**: bot permainan (AlphaGo)
#
# ---
#
# ## 5. Jenis-Jenis Machine Learning System
#
# ### a. Supervised Learning
# Model belajar dari data berlabel $(x_i, y_i)$.
# Contoh algoritma:
# - Linear Regression
# - Logistic Regression
# - Decision Tree
# - SVM
# - Neural Network
#
# ### b. Unsupervised Learning
# Model belajar dari data tanpa label $x_i$.
# Contoh:
# - Clustering: K-Means, DBSCAN
# - Dimensionality Reduction: PCA
# - Anomaly Detection
#
# ### c. Semi-supervised Learning
# Gabungan data berlabel dan tidak berlabel.
# Contoh: face recognition pada Google Photos
#
# ### d. Reinforcement Learning
# Agent belajar dari pengalaman untuk memaksimalkan reward $R$.
# Agent membangun policy $\pi(s)$:
# $$
# \pi^* = \arg\max_\pi \mathbb{E}\left[ \sum_t \gamma^t R_t \right]
# $$
# di mana:
# - $\gamma$: discount factor
# - $R_t$: reward di waktu $t$
#
# ---
#
# ## 6. Cara Model Belajar
#
# ### a. Batch Learning
# - Model dilatih dengan seluruh data sekaligus (offline)
# - Tidak bisa belajar dari data baru tanpa retrain
#
# ### b. Online Learning
# - Model belajar inkremental dari data baru (streaming data)
#
# ### c. Instance-based Learning
# - Model membandingkan data baru dengan data lama
#
# ### d. Model-based Learning
# - Model mempelajari fungsi $f$:
# $
# \hat{y} = f(x)
# $
# untuk membuat generalisasi
#
# ---
#
# ## 7. Tantangan dalam Machine Learning
#
# - Data tidak cukup $\Rightarrow$ tidak bisa belajar pola
# - Data tidak representatif $\Rightarrow$ tidak mencerminkan kondisi nyata
# - Data berkualitas buruk (noise, outlier)
# - Fitur tidak relevan (butuh feature selection/engineering)
# - **Overfitting**: model terlalu cocok dengan data latih (high variance)
# - **Underfitting**: model terlalu sederhana (high bias)
#
# ---
#
# ## 8. Evaluasi dan Validasi Model
#
# - **Testing & validation:** uji model dengan data baru
# - **Hyperparameter tuning:** cari parameter terbaik
# - **Cek data mismatch:** pastikan data latih & uji konsisten
